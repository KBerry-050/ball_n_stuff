# %%
import pandas as pd
import numpy as np

# %%
pip install cfbd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# import package and CFB data from collegefootballdata.com
from __future__ import print_function
import time
import cfbd
from cfbd.rest import ApiException
from pprint import pprint

# configure authorization
configuration = cfbd.Configuration()
configuration.api_key['Authorization'] = '764WJr7XOG8TwqDCfJpNM3PUdPH9Iu5GQNq7pfXCzdDkm8DESnKeaaNMO3DlT9OW'
configuration.api_key_prefix['Authorization'] = 'Bearer'

# get game data for 2010 to 2021 seasons
api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))
games_2010 = api_instance.get_games(year=2010)
games_2011 = api_instance.get_games(year=2011)
games_2012 = api_instance.get_games(year=2012)
games_2013 = api_instance.get_games(year=2013)
games_2014 = api_instance.get_games(year=2014)
games_2015 = api_instance.get_games(year=2015)
games_2016 = api_instance.get_games(year=2016)
games_2017 = api_instance.get_games(year=2017)
games_2018 = api_instance.get_games(year=2018)
games_2019 = api_instance.get_games(year=2019)
games_2020 = api_instance.get_games(year=2020)
games_2021 = api_instance.get_games(year=2021)

# %%
# get team record data for 2010 to 2021 seasons
api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))
team_records_2010 = api_instance.get_team_records(year=2010)
team_records_2011 = api_instance.get_team_records(year=2011)
team_records_2012 = api_instance.get_team_records(year=2012)
team_records_2013 = api_instance.get_team_records(year=2013)
team_records_2014 = api_instance.get_team_records(year=2014)
team_records_2015 = api_instance.get_team_records(year=2015)
team_records_2016 = api_instance.get_team_records(year=2016)
team_records_2017 = api_instance.get_team_records(year=2017)
team_records_2018 = api_instance.get_team_records(year=2018)
team_records_2019 = api_instance.get_team_records(year=2019)
team_records_2020 = api_instance.get_team_records(year=2020)
team_records_2021 = api_instance.get_team_records(year=2021)

# %%
# get recruiting data for 2010 to 2021 seasons
api_instance_recruiting = cfbd.RecruitingApi(cfbd.ApiClient(configuration))
recruiting_2010 = api_instance_recruiting.get_recruiting_teams(year=2010)
recruiting_2011 = api_instance_recruiting.get_recruiting_teams(year=2011)
recruiting_2012 = api_instance_recruiting.get_recruiting_teams(year=2012)
recruiting_2013 = api_instance_recruiting.get_recruiting_teams(year=2013)
recruiting_2014 = api_instance_recruiting.get_recruiting_teams(year=2014)
recruiting_2015 = api_instance_recruiting.get_recruiting_teams(year=2015)
recruiting_2016 = api_instance_recruiting.get_recruiting_teams(year=2016)
recruiting_2017 = api_instance_recruiting.get_recruiting_teams(year=2017)
recruiting_2018 = api_instance_recruiting.get_recruiting_teams(year=2018)
recruiting_2019 = api_instance_recruiting.get_recruiting_teams(year=2019)
recruiting_2020 = api_instance_recruiting.get_recruiting_teams(year=2020)
recruiting_2021 = api_instance_recruiting.get_recruiting_teams(year=2021)
recruiting_2021
# Out:
# [{'points': 327.91, 'rank': 1, 'team': 'Alabama', 'year': 2021},
#  {'points': 309.49, 'rank': 2, 'team': 'Ohio State', 'year': 2021},
#  {'points': 294.55, 'rank': 3, 'team': 'Georgia', 'year': 2021},
#  {'points': 291.37, 'rank': 4, 'team': 'LSU', 'year': 2021},
#  {'points': 291.2, 'rank': 5, 'team': 'Clemson', 'year': 2021},
#  {'points': 287.38, 'rank': 6, 'team': 'Oregon', 'year': 2021},
#  {'points': 285.35, 'rank': 7, 'team': 'Texas A&M', 'year': 2021},
#  {'points': 280.72, 'rank': 8, 'team': 'USC', 'year': 2021},
#  {'points': 269.15, 'rank': 9, 'team': 'Notre Dame', 'year': 2021},
#  {'points': 268.77, 'rank': 10, 'team': 'Michigan', 'year': 2021},
#  {'points': 267.92, 'rank': 11, 'team': 'Oklahoma', 'year': 2021},
#  {'points': 263.12, 'rank': 12, 'team': 'Miami', 'year': 2021},
#  {'points': 261.62, 'rank': 13, 'team': 'Florida', 'year': 2021},
#  {'points': 253.91, 'rank': 14, 'team': 'North Carolina', 'year': 2021},
# ...

# %%
# get return playing production data for 2014 to 2021 seasons
api_instance_players = cfbd.PlayersApi(cfbd.ApiClient(configuration))
returning_prod_2014 = api_instance_players.get_returning_production(year=2014)
returning_prod_2015 = api_instance_players.get_returning_production(year=2015)
returning_prod_2016 = api_instance_players.get_returning_production(year=2016)
returning_prod_2017 = api_instance_players.get_returning_production(year=2017)
returning_prod_2018 = api_instance_players.get_returning_production(year=2018)
returning_prod_2019 = api_instance_players.get_returning_production(year=2019)
returning_prod_2020 = api_instance_players.get_returning_production(year=2020)
returning_prod_2021 = api_instance_players.get_returning_production(year=2021)

# %%
# get team talent composite ranking data for 2015 to 2021 seasons
api_instance_teams = cfbd.TeamsApi(cfbd.ApiClient(configuration))
team_talent_2015 = api_instance_teams.get_talent(year=2015)
team_talent_2016 = api_instance_teams.get_talent(year=2016)
team_talent_2017 = api_instance_teams.get_talent(year=2017)
team_talent_2018 = api_instance_teams.get_talent(year=2018)
team_talent_2019 = api_instance_teams.get_talent(year=2019)
team_talent_2020 = api_instance_teams.get_talent(year=2020)
team_talent_2021 = api_instance_teams.get_talent(year=2021)

# %%
type(team_talent_2016)
# Out:
# list

# %%
test3 = [{'school': 'Alabama', 'talent': 981.9, 'year': 2015},
 {'school': 'USC', 'talent': 926.71, 'year': 2015},
 {'school': 'Ohio State', 'talent': 907.32, 'year': 2015},
 {'school': 'Florida State', 'talent': 889.92, 'year': 2015},
 {'school': 'LSU', 'talent': 889.37, 'year': 2015},
 {'school': 'Georgia', 'talent': 877.74, 'year': 2015},
 {'school': 'Auburn', 'talent': 865.41, 'year': 2015},
 {'school': 'Notre Dame', 'talent': 857.33, 'year': 2015},
 {'school': 'Michigan', 'talent': 851.12, 'year': 2015},
 {'school': 'Texas A&M', 'talent': 830.34, 'year': 2015},
 {'school': 'Texas', 'talent': 821.26, 'year': 2015},
 {'school': 'Tennessee', 'talent': 810.53, 'year': 2015},
 {'school': 'Clemson', 'talent': 807.56, 'year': 2015},
 {'school': 'UCLA', 'talent': 793.22, 'year': 2015},
 {'school': 'Florida', 'talent': 789.79, 'year': 2015},
 {'school': 'Oklahoma', 'talent': 775.9, 'year': 2015},
 {'school': 'Miami', 'talent': 773.23, 'year': 2015},
 {'school': 'Stanford', 'talent': 765.98, 'year': 2015},
 {'school': 'Ole Miss', 'talent': 764.34, 'year': 2015},
 {'school': 'Oregon', 'talent': 757.52, 'year': 2015},
 {'school': 'North Carolina Central', 'talent': 14.26, 'year': 2015},
 {'school': 'Alabama A&M', 'talent': 13.33, 'year': 2015},
 {'school': 'Montana State', 'talent': 11.86, 'year': 2015},
 {'school': 'Butler', 'talent': 9.96, 'year': 2015},
 {'school': 'Gardner-Webb', 'talent': 8.58, 'year': 2015},
 {'school': 'Monmouth', 'talent': 7.93, 'year': 2015},
 {'school': 'Holy Cross', 'talent': 7.45, 'year': 2015},
 {'school': 'Drake', 'talent': 7.43, 'year': 2015},
 {'school': 'Maine', 'talent': 7.24, 'year': 2015},
 {'school': 'Lehigh', 'talent': 6.66, 'year': 2015},
 {'school': 'Stetson', 'talent': 6.66, 'year': 2015},
 {'school': 'Arkansas-Pine Bluff', 'talent': 6.66, 'year': 2015},
 {'school': 'Southern Utah', 'talent': 6.66, 'year': 2015},
 {'school': 'UC Davis', 'talent': 6.66, 'year': 2015},
 {'school': 'South Dakota', 'talent': 3.36, 'year': 2015},
 {'school': 'Robert Morris', 'talent': 3.06, 'year': 2015},
 {'school': 'Dartmouth', 'talent': 2.96, 'year': 2015},
 {'school': 'Marist', 'talent': 2.63, 'year': 2015},
 {'school': 'Howard', 'talent': 2.22, 'year': 2015},
 {'school': 'St Francis (PA)', 'talent': 1.74, 'year': 2015}]
type(test3)
# Out:
# list

# %%
test3df = pd.DataFrame(test3)
test3df
# Out:
#               school  talent  year
# 0            Alabama  981.90  2015
# 1                USC  926.71  2015
# 2         Ohio State  907.32  2015
# 3      Florida State  889.92  2015
# 4                LSU  889.37  2015
# ..               ...     ...   ...
# 227    Robert Morris    3.06  2015
# 228        Dartmouth    2.96  2015
# 229           Marist    2.63  2015
# 230           Howard    2.22  2015
# 231  St Francis (PA)    1.74  2015
#
# [232 rows x 3 columns]

# %%
team_talent_2016_df = pd.DataFrame(team_talent_2016)
team_talent_2016_df
# Out:
#                                                      0
# 0    {'school': 'Alabama', 'talent': 982.66, 'year'...
# 1    {'school': 'USC', 'talent': 936.86, 'year': 2016}
# 2    {'school': 'LSU', 'talent': 917.72, 'year': 2016}
# 3    {'school': 'Florida State', 'talent': 906.64, ...
# 4    {'school': 'Ohio State', 'talent': 902.46, 'ye...
# ..                                                 ...
# 232  {'school': 'Central Connecticut', 'talent': 6....
# 233  {'school': 'San Diego', 'talent': 6.66, 'year'...
# 234  {'school': 'Bryant', 'talent': 6.24, 'year': 2...
# 235  {'school': 'North Carolina A&T', 'talent': 3.8...
# 236  {'school': 'St Francis (PA)', 'talent': 1.74, ...
#
# [237 rows x 1 columns]

# %%
# get recruiting data for 2010-2021 seasons
import requests

headers = {
    'accept': 'application/json',
    'Authorization': 'Bearer 764WJr7XOG8TwqDCfJpNM3PUdPH9Iu5GQNq7pfXCzdDkm8DESnKeaaNMO3DlT9OW',
}

params = {
    'year': '2010',
    'year': '2011',
    'year': '2012',
    'year': '2013',
    'year': '2014',
    'year': '2015',
    'year': '2016',
    'year': '2017',
    'year': '2018',
    'year': '2019',
    'year': '2020',
    'year': '2021',
}

response = requests.get('https://api.collegefootballdata.com/recruiting/teams', params=params, headers=headers)

# %%
sfd
