# %% [markdown]
# At the top level is the Game class. A game, in the Yahoo! fantasy sense, is individual leagues you are part of – both active and historical.
#
# Next comes the League class. This is a particular instance of a game. It represents a particular season and game code that you played in. The league is found by its unique league ID.
#
# Next level down in the hierarchy is the Team class. Within a league there are individual teams. The teams can be your own teams that you owned or one of your opponents.
#
# Finally at the lowest level are individual players that either exist on a team or are free agents. There is no Player class to represent this level.

# %%
pip install yahoo_fantasy_api
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for yahoo_fantasy_api: filename=yahoo_fantasy_api-2.6.0-py3-none-any.whl size=26080 sha256=114ef1ced028fbb2b9c8771ef3a40556a55a8ba117bb1984bd6eaa9a80cdee07
#   Stored in directory: /Users/kyleberry/Library/Caches/pip/wheels/b0/f9/66/a3d5ab1724622e10ffa0138960f2fd14aa134741c4fb58092f
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13704 sha256=11b56eda40cb24574bdf3247e1777b2632ccd9e0640ed0c74cd41a6c184cfe06
#   Stored in directory: /Users/kyleberry/Library/Caches/pip/wheels/56/ea/58/ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c
# ...
#   Created wheel for yahoo_oauth: filename=yahoo_oauth-2.0-py3-none-any.whl size=8154 sha256=aae2e6c5a9f664601b8d1b1530bb1d5e7f147321a7fd1edd9ba803a4e7da5326
# ...

# %%
pip install --upgrade pip
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 5.3 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 22.2.2
#     Uninstalling pip-22.2.2:
#       Successfully uninstalled pip-22.2.2
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yahoo_fantasy_api

# %%
from yahoo_oauth import OAuth2
import json

creds = {'consumer_key': 'dj0yJmk9dzUxTE1RTDc4R3phJmQ9WVdrOVpESm9USGsxWjFjbWNHbzlNQT09JnM9Y29uc3VtZXJzZWNyZXQmc3Y9MCZ4PWMy', 'consumer_secret': 'dfb6c0ffe7c1f24a4103faa26cb6ed9edfb0f1bb'}
with open(args['<json>'], "w") as f:
   f.write(json.dumps(creds))
oauth = OAuth2(None, None, from_file='oauth2.json')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-3440e9a7c606> in <module>
#       3
#       4 creds = {'consumer_key': 'dj0yJmk9dzUxTE1RTDc4R3phJmQ9WVdrOVpESm9USGsxWjFjbWNHbzlNQT09JnM9Y29uc3VtZXJzZWNyZXQmc3Y9MCZ4PWMy', 'consumer_secret': 'dfb6c0ffe7c1f24a4103faa26cb6ed9edfb0f1bb'}
# ----> 5 with open(args['<json>'], "w") as f:
#       6    f.write(json.dumps(creds))
#       7 oauth = OAuth2(None, None, from_file='oauth2.json')
#
# NameError: name 'args' is not defined

# %%
pip install yahoo_oauth
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
 
# Data to be written
dictionary = {
    "consumer_key": "dj0yJmk9dzUxTE1RTDc4R3phJmQ9WVdrOVpESm9USGsxWjFjbWNHbzlNQT09JnM9Y29uc3VtZXJzZWNyZXQmc3Y9MCZ4PWMy",
    "consumer_secret": "dfb6c0ffe7c1f24a4103faa26cb6ed9edfb0f1bb"
}
 
# Serializing json
json_object = json.dumps(dictionary, indent=4)
 
# Writing to sample.json
with open("yahoo_keys.json", "w") as outfile:
    outfile.write(json_object)

# %%
from yahoo_oauth import OAuth2

oauth = OAuth2(None,None, from_file='yahoo_keys.json')
# Out:
# [2022-10-24 09:13:54,222 DEBUG] [yahoo_oauth.oauth.__init__] Checking
# [2022-10-24 09:13:54,225 DEBUG] [yahoo_oauth.oauth.handler] AUTHORIZATION URL : https://api.login.yahoo.com/oauth2/request_auth?redirect_uri=oob&response_type=code&client_id=dj0yJmk9dzUxTE1RTDc4R3phJmQ9WVdrOVpESm9USGsxWjFjbWNHbzlNQT09JnM9Y29uc3VtZXJzZWNyZXQmc3Y9MCZ4PWMy
# Enter verifier : a4nj8jx

# %%
# my_team = yahoo_fantasy_api.team.Team(oauth, 175221)

import yahoo_fantasy_api.team as team
import yahoo_fantasy_api.game as game
import yahoo_fantasy_api.league as league

# %%
my_team = team(oauth, 175221)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-a149584e132c> in <module>
# ----> 1 my_team = team(oauth, 175221)
#
# TypeError: 'module' object is not callable

# %%
#team.Team(oauth,175221)
game.Game(oauth, 'nfl').league_ids(year="2022")
# Out:
# ['414.l.175221', '414.l.209465']

# %%
league.League(oauth, '414.l.175221').current_week()
# Out:
# 7

# %%
league.League(oauth, '414.l.175221').draft_results()
# Out:
# [{'pick': 1, 'round': 1, 'team_key': '414.l.175221.t.7', 'player_id': 32711},
#  {'pick': 2, 'round': 1, 'team_key': '414.l.175221.t.10', 'player_id': 30121},
#  {'pick': 3, 'round': 1, 'team_key': '414.l.175221.t.9', 'player_id': 30423},
#  {'pick': 4, 'round': 1, 'team_key': '414.l.175221.t.5', 'player_id': 32692},
#  {'pick': 5, 'round': 1, 'team_key': '414.l.175221.t.6', 'player_id': 30182},
#  {'pick': 6, 'round': 1, 'team_key': '414.l.175221.t.11', 'player_id': 33393},
#  {'pick': 7, 'round': 1, 'team_key': '414.l.175221.t.2', 'player_id': 30154},
#  {'pick': 8, 'round': 1, 'team_key': '414.l.175221.t.1', 'player_id': 28534},
#  {'pick': 9, 'round': 1, 'team_key': '414.l.175221.t.12', 'player_id': 26686},
#  {'pick': 10, 'round': 1, 'team_key': '414.l.175221.t.3', 'player_id': 27581},
#  {'pick': 11, 'round': 1, 'team_key': '414.l.175221.t.8', 'player_id': 29279},
#  {'pick': 12, 'round': 1, 'team_key': '414.l.175221.t.4', 'player_id': 30161},
# ...

# %%
league.standings()
# Out:
# [{'team_key': '414.l.175221.t.6',
#   'name': 'CeeDeez Nutz',
#   'rank': '1',
#   'playoff_seed': '1',
#   'outcome_totals': {'wins': '6',
#    'losses': 0,
#    'ties': 0,
#    'percentage': '1.000'},
#   'streak': {'type': 'win', 'value': '6'},
#   'points_for': '796.58',
#   'points_against': 635.6800000000001},
#  {'team_key': '414.l.175221.t.12',
#   'name': "Michael's Team",
#   'rank': '2',
#   'playoff_seed': '2',
#   'outcome_totals': {'wins': '5',
#    'losses': '1',
#    'ties': 0,
#    'percentage': '.833'},
#   'streak': {'type': 'win', 'value': '2'},
#   'points_for': '880.40',
#   'points_against': 630.2199999999999},
#  {'team_key': '414.l.175221.t.9',
#   'name': 'The Public Defender',
#   'rank': '3',
#   'playoff_seed': '3',
#   'outcome_totals': {'wins': '5',
#    'losses': '1',
#    'ties': 0,
#    'percentage': '.833'},
#   'streak': {'type': 'win', 'value': '4'},
#   'points_for': '755.26',
#   'points_against': 628.72},
#  {'team_key': '414.l.175221.t.1',
# ...

# %%
league.teams()
# Out:
# {'414.l.175221.t.6': {'team_key': '414.l.175221.t.6',
#   'team_id': '6',
#   'name': 'CeeDeez Nutz',
#   'url': 'https://football.fantasysports.yahoo.com/f1/175221/6',
#   'team_logos': [{'team_logo': {'size': 'large',
#      'url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/2ef4fd13febe19a7a7bc7eb9baf6cd2325b062c1576b881f26c32cb418771793.jpg'}}],
#   'waiver_priority': 4,
#   'number_of_moves': '34',
#   'number_of_trades': '2',
#   'roster_adds': {'coverage_type': 'week', 'coverage_value': 7, 'value': '4'},
#   'league_scoring_type': 'head',
#   'has_draft_grade': 1,
#   'draft_grade': 'B',
#   'draft_recap_url': 'https://football.fantasysports.yahoo.com/f1/175221/6/draftrecap',
#   'managers': [{'manager': {'manager_id': '6',
#      'nickname': 'Chris',
#      'guid': 'UQN3KWZSD7XMK6X2XNFWVORBDQ',
#      'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#      'felo_score': '900',
# ...

# %%
teams_dict = league.teams()

# %%
for k,v in teams_dict.items():
    print(k,v)
# Out:
# 414.l.175221.t.6 {'team_key': '414.l.175221.t.6', 'team_id': '6', 'name': 'CeeDeez Nutz', 'url': 'https://football.fantasysports.yahoo.com/f1/175221/6', 'team_logos': [{'team_logo': {'size': 'large', 'url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/2ef4fd13febe19a7a7bc7eb9baf6cd2325b062c1576b881f26c32cb418771793.jpg'}}], 'waiver_priority': 4, 'number_of_moves': '34', 'number_of_trades': '2', 'roster_adds': {'coverage_type': 'week', 'coverage_value': 7, 'value': '4'}, 'league_scoring_type': 'head', 'has_draft_grade': 1, 'draft_grade': 'B', 'draft_recap_url': 'https://football.fantasysports.yahoo.com/f1/175221/6/draftrecap', 'managers': [{'manager': {'manager_id': '6', 'nickname': 'Chris', 'guid': 'UQN3KWZSD7XMK6X2XNFWVORBDQ', 'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg', 'felo_score': '900', 'felo_tier': 'diamond'}}]}
# ...

# %%
team_name_dict = {}
for key,value in teams_dict.items():
    print(key, '=', value['name'])
    
#team_name_dict
# Out:
# 414.l.175221.t.6 = CeeDeez Nutz
# 414.l.175221.t.12 = Michael's Team
# 414.l.175221.t.9 = The Public Defender
# 414.l.175221.t.1 = Donald
# 414.l.175221.t.5 = GK
# 414.l.175221.t.10 = The Chefs
# 414.l.175221.t.7 = Marty Daniels
# 414.l.175221.t.11 = The Fellas
# 414.l.175221.t.8 = KB
# 414.l.175221.t.2 = Gorrona
# 414.l.175221.t.4 = The Lil' Maxwells
# 414.l.175221.t.3 = mormon milfhunter

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# Out:
# [2022-10-24 11:39:39,318 DEBUG] [matplotlib.__init__.wrapper] (private) matplotlib data path: /Users/kyleberry/opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data
# [2022-10-24 11:39:39,319 DEBUG] [matplotlib.__init__.wrapper] matplotlib data path: /Users/kyleberry/opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data
# [2022-10-24 11:39:39,323 DEBUG] [matplotlib.__init__.wrapper] CONFIGDIR=/Users/kyleberry/.matplotlib
# [2022-10-24 11:39:39,325 DEBUG] [matplotlib.__init__.<module>] matplotlib version 3.3.2
# [2022-10-24 11:39:39,325 DEBUG] [matplotlib.__init__.<module>] interactive is False
# [2022-10-24 11:39:39,325 DEBUG] [matplotlib.__init__.<module>] platform is darwin
# ...

# %%
df = pd.DataFrame(teams_dict)
df
# Out:
#                                                             414.l.175221.t.6  \
# team_key                                                    414.l.175221.t.6
# team_id                                                                    6
# name                                                            CeeDeez Nutz
# url                        https://football.fantasysports.yahoo.com/f1/17...
# team_logos                 [{'team_logo': {'size': 'large', 'url': 'https...
# waiver_priority                                                            4
# number_of_moves                                                           34
# number_of_trades                                                           2
# roster_adds                {'coverage_type': 'week', 'coverage_value': 7,...
# league_scoring_type                                                     head
# has_draft_grade                                                            1
# ...

# %%
teams_dict
# Out:
# {'414.l.175221.t.6': {'team_key': '414.l.175221.t.6',
#   'team_id': '6',
#   'name': 'CeeDeez Nutz',
#   'url': 'https://football.fantasysports.yahoo.com/f1/175221/6',
#   'team_logos': [{'team_logo': {'size': 'large',
#      'url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/2ef4fd13febe19a7a7bc7eb9baf6cd2325b062c1576b881f26c32cb418771793.jpg'}}],
#   'waiver_priority': 4,
#   'number_of_moves': '34',
#   'number_of_trades': '2',
#   'roster_adds': {'coverage_type': 'week', 'coverage_value': 7, 'value': '4'},
#   'league_scoring_type': 'head',
#   'has_draft_grade': 1,
#   'draft_grade': 'B',
#   'draft_recap_url': 'https://football.fantasysports.yahoo.com/f1/175221/6/draftrecap',
#   'managers': [{'manager': {'manager_id': '6',
#      'nickname': 'Chris',
#      'guid': 'UQN3KWZSD7XMK6X2XNFWVORBDQ',
#      'image_url': 'https://s.yimg.com/ag/images/default_user_profile_pic_64sq.jpg',
#      'felo_score': '900',
# ...

# %%
team_name_dict
# Out:
# {}
